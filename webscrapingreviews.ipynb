# %%
import requests
import pandas as pd
import json
import os
from dotenv import load_dotenv
from openai import OpenAI


os.getenv("API_KEY")
client = OpenAI()

# %%
def get_products(page=1, page_size=90, category="tents"):
    headers = {
        'authority': 'www.rei.com',
        'accept': '*/*',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8,hu;q=0.7',
        'priority': 'u=1, i',
        'referer': f'https://www.rei.com/c/{category}?page={page}',
        'sec-ch-ua': '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
    }

    params = {
        'json': 'true',
        'page': page,
        'pagesize': page_size,
    }

    return requests.get(f'https://www.rei.com/c/{category}', params=params, headers=headers)

def get_reviews(product_id, limit=12, offset=0):
    headers = {
        'Accept': '*/*',
        'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8,hu;q=0.7',
        'Connection': 'keep-alive',
        'Origin': 'https://www.rei.com',
        'Referer': 'https://www.rei.com/product/189281/alpine-mountain-gear-weekender-tent-4',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'cross-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
        'sec-ch-ua': '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        "resource": "reviews",
        "action": "REVIEWS_N_STATS",
        "filter": [
            f"productid:eq:{product_id}",
            "contentlocale:eq:en*,en_US,en_US",
            "isratingsonly:eq:false"
        ],
        "filter_reviews": "contentlocale:eq:en*,en_US,en_US",
        "include": "authors,products",
        "filteredstats": "reviews",
        "Stats": "Reviews",
        "limit": limit,
        "offset": offset,
        "sort": "submissiontime:desc",
        "passkey": "thvpbov9ywkkl4nkhbeq0wm1i",
        "apiversion": "5.5",
        "displaycode": "15372-en_us"
    }


    return requests.get(
        'https://api.bazaarvoice.com/data/reviews.json',
        headers=headers, params=params
    )
    
def review_themes(review_json_string):
  return client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
      {
        "role": "system",
        "content": [
          {
            "type": "text",
            "text": "You will be provided a product review in the following json format:\n'{\"rating\": 1, \"title\": \"Poor flap zipper\", \"ReviewText\": \"After one use, I was unable to get the zipper to work properly with the front flap.  REI did take it back with no issues.\", \"OriginalProductName\": \"ALPS Mountaineering Camp Creek 6 Tent\"}'\n\nyou will categorise the themes related to the review outputted in a valid json format like so:\n{\"themes\":[\"theme1\", \"theme2\", \"theme3\"]}"
          }
        ]
      },
      {
        "role": "user",
        "content": review_json_string
      }
    ],
    temperature=1,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )

# %%
product_response = get_products()
product_response_json = product_response.json()

product_ids = [x["prodId"] for x in product_response_json["searchResults"]["results"]]

# %%
review_list = []
for product_id in product_ids[:10]:
    print(product_id)
    
    review_response = get_reviews(product_id)
    review_list.append(review_response)
# Out:
# 189281
# 227740
# 204311
# 202274
# 189270
# 185632
# 189282
# 204308
# 202982
# 164811

# %%
list_of_clean_reviews = []
for review_response in review_list:
    review_response_json = review_response.json()
    reviews = review_response_json["Results"]
    clean_reviews = [{"review_id": review["Id"], "product_id": review["ProductId"], "rating": review["Rating"], 
                      "title": review["Title"], "ReviewText": review["ReviewText"], 
                      "OriginalProductName": review["OriginalProductName"]} for review in reviews]
    list_of_clean_reviews.extend(clean_reviews)

# %%
bad_reviews = [x for x in list_of_clean_reviews if x["rating"] < 3]

# %%
for review_payload in bad_reviews:
    print(review_payload)
    review_payload_string = json.dumps(review_payload)
    themes_response = review_themes(review_payload_string)
    theme_string = themes_response.choices[0].message.content
    theme_response = json.loads(theme_string)
    review_payload["themes"] = theme_response["themes"]
# Out:
# {'review_id': '346891208', 'product_id': '189281', 'rating': 1, 'title': 'Poor zipper', 'ReviewText': 'The zipper broke on 1st use, just separated in the middle. And we could not get it back on the track because there is no start anywhere.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 4', 'themes': ['zipper quality', 'durability', 'customer service']}
# {'review_id': '256830169', 'product_id': '189281', 'rating': 1, 'title': 'Product delivered broken', 'ReviewText': 'Tent arrived with the shock-cord in one of the tent poles already snapped.  When I tried to assemble a second pole that shock-cord snapped too.  Good thing we set it up before attempting to go camping.  This was purchased via the REI Outlet.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 4'}
# {'review_id': '345639673', 'product_id': '204311', 'rating': 1, 'title': 'Arrived Used and With Broken Parts', 'ReviewText': 'Ordered this for family camping trips. Thank goodness I put it together ahead of our trip. The poles came with scrapes and scratches and one of the shock cords was broken.\n\nI would return, but REI didn’t have the correct footprint in stock so I had to get it from somewhere else. Additionally, REI does not have these tents in stock, so a replacement is not possible.\n\nI won’t buy anything else if I can’t get all the parts at REI. Not worth the hassle of being stuck with something subpar.', 'OriginalProductName': 'The North Face Wawona 6 Tent'}
# {'review_id': '345446761', 'product_id': '204311', 'rating': 2, 'title': 'Buy a different tent', 'ReviewText': 'I have the previous version of this tent I guess. Looks like they may have made some changes. I have had mine for a few years now but have only used it half a dozen times. It’s not my favorite tent and now the floor almost seems like it has shrank. When I set it up there is a section of the floor that is raised up with a fold in it. I’t weird. I talked to REI about it and they don’t take returns for tents after a year (or something like that). I want to exchange it for a different one like maybe the REI Kingdom. I’ll try and get it set up in my backyard and snap some pictures of what’s going on. REI told me to contact North Face directly. I have a trip planned next month and am not excited about using this tent but am not about to shell out more money for a better one until I hear back from North Face.', 'OriginalProductName': 'The North Face Wawona 6 Tent'}
# {'review_id': '344760907', 'product_id': '202274', 'rating': 1, 'title': 'Difficult to assemble', 'ReviewText': 'This is my 4th REI tent. I love the first three but this one is going back for a number of reasons. My first issue is with assembling the tent. I had my husband helping me with this and I am surprised we didn’t come to blows because this was the most frustrating and difficult tent I have ever tried to assemble. For context, I have a Base Camp 6 that I have put up by myself many times so it isn’t lack of experience. Once we finally got the tent up, the next thing I noticed was the lack of storage inside the tent. There is room for pockets at both ends of the tent but there aren’t any at the back or on the sides of the tent. I can’t be the only one who likes a pocket near my head for glasses and head lamp storage. When we took the tent down at the end of our trip, it was an absolute nightmare fitting back in the bag it came in. If you don’t fold it just right, it isn’t going back in that bag without a fight. Do not attempt this while hangry. On a positive note, the tent did keep us dry during a couple of strong storms. The rainfly doesn’t look like it would be protective but it does a solid job keeping the rain out. On a more positive note, REI has a very generous return policy for members and I am able to return this tent and get one that is a better fit for me. I would not repurchase or recommend this particular tent.', 'OriginalProductName': 'REI Co-op Skyward 4 Tent'}
# {'review_id': '340559495', 'product_id': '202274', 'rating': 2, 'title': 'Had to return', 'ReviewText': 'I love REI and a great deal so when I saw this tent on sale I had to buy it. Sadly I also had to return it after spending a day trying to set it up. I see someone else had a similar comment about the fit of the poles and wished I  would have read that review before buying it because I could have saved hours wondering if I was doing something wrong setting it up. I really would have loved this tent but I will be looking for a new one.', 'OriginalProductName': 'REI Co-op Skyward 4 Tent'}
# {'review_id': '345125723', 'product_id': '189270', 'rating': 2, 'title': 'Leaky tent', 'ReviewText': 'I took this tent out one time with the rain fly on. It started raining and the zipper started leaking and water got into the tent. Not only that but the rain fly barely even covers the netting of the tent itself. Any rain with wind will cause it to hit the netting and get your tent wet. It’s a great tent if you’re not planning on camping in the rain.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3'}
# {'review_id': '344001528', 'product_id': '189270', 'rating': 1, 'title': 'Cheap quality', 'ReviewText': 'Cheap quality, poor design. I expected better from REI.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3'}
# {'review_id': '338533330', 'product_id': '189270', 'rating': 1, 'title': '“Duped” by outlet price', 'ReviewText': 'Can’t believe I found this exact tent at Costco for same “Outlet” price at REI . I thought REI was giving me a deal ? Not so . Last time I buy from your company.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3'}
# {'review_id': '323971222', 'product_id': '189270', 'rating': 1, 'title': 'Great in dry weather', 'ReviewText': "The bathtub leaks on this tent. It's not reliable in the rain.", 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3'}
# {'review_id': '313104146', 'product_id': '189270', 'rating': 2, 'title': 'Cheap and limited instructions!', 'ReviewText': 'Purchased this tent thinking it would be a cheap starter tent to get back into camping. Cheap us right. The material seemed paper thin and there were limited instructions. The rain fly provides little protection above the door and is complicate to install. I immediately returned it and will be investing in a better quality brand.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3'}
# {'review_id': '308366193', 'product_id': '189270', 'rating': 1, 'title': None, 'ReviewText': "This tent has absolutely no instruction for how to use the rainfly.  The instructions say to use youtube but I can't find naything on youtube", 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3'}
# {'review_id': '346895284', 'product_id': '185632', 'rating': 2, 'title': 'I’m concerned about longevity', 'ReviewText': 'Seems nice mostly, if it holds up. But the fly is tearing at 2 seams after the first use so I’m not feeling confident.', 'OriginalProductName': 'REI Co-op Half Dome SL 2+ Tent'}
# {'review_id': '345567461', 'product_id': '185632', 'rating': 1, 'title': 'Bent Poles/ripped fly', 'ReviewText': 'The poles bent and ripped into fly with one day of wind. Of course this happened 3 days after the 1 year return for REI.', 'OriginalProductName': 'REI Co-op Half Dome SL 2+ Tent'}
# {'review_id': '305343712', 'product_id': '189282', 'rating': 2, 'title': 'Directions incomplete and not going to be water pr', 'ReviewText': "The rain fly looks cool but doesnt cover the no seum mesh at the poles when the wind blows and it barely covers the side mesh.  The instructions omit the rain fly and after working in sporting goods back in college and setting up 100's of dome tents I couldn't figure it out.  Fortunately didn't rain.   I gave it 2 stars because the poles seem sturdy but you cant get parts for it so stick to a  bigger name brand tent.", 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 6'}
# {'review_id': '263336847', 'product_id': '189282', 'rating': 2, 'title': 'Spacious but challenging', 'ReviewText': 'The tent is spacious but the zippers often get stuck and it was impossible to fold back up and fit into the storage bag.', 'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 6'}
# {'review_id': '346866927', 'product_id': '204308', 'rating': 1, 'title': 'Poles bent randomly', 'ReviewText': "The poles bent and North Face wouldn't take responsibility for it", 'OriginalProductName': 'The North Face Stormbreak 3 Tent'}
# {'review_id': '345641820', 'product_id': '202982', 'rating': 2, 'title': 'Save your money', 'ReviewText': 'The tent was nice, however I was only able to sleep in it 5 total nights because once any sort of wind came through, the poles bent and I had to cut my camping trip short since it became unusable. I expected a tent of this price to stand through one storm.', 'OriginalProductName': 'REI Co-op Wonderland 6 Tent'}
# {'review_id': '336538558', 'product_id': '202982', 'rating': 1, 'title': 'Worst tent I have ever owned', 'ReviewText': 'This tent had no ability to stand up to wind. We had some wind camping in the desert and multiple poles snapped and the tent collapsed, this is with it properly staked and guy-lined down mind you. This was on our 5th or 6th use of the tent. I\'ve been camping for most of my life and have camped many times in heavier winds with tents that survived just fine. \n\nREI then refused to accept a return for "damage", even though their product is flawed. At the time of writing this review it has 22% 1 star reviews and most mention snapped poles, many even during setup. We haven\'t even had this tent a year and they won\'t accept a return or cover it under warranty.  So much for the "100% satisfaction guarantee", the tent is literally still within the "I don\'t like it" return window, but because it completely failed us and is damaged, REI won\'t take it back. \n\nMy experience with this horrible tent and REI telling me to pound sand is the type of thing that will turn me from a lifetime REI customer to someone who won\'t be shopping at REI again.', 'OriginalProductName': 'REI Co-op Wonderland 6 Tent'}
# {'review_id': '319993468', 'product_id': '202982', 'rating': 2, 'title': 'Great, except lasted two times.', 'ReviewText': 'We purchased the tent, footprint, and mudroom for 6-person Wonderland to introduce our kids to camping (parents are experienced hikers/campers).  On the second use one of the tension poles tore a huge hole in the mesh. Functionally rendering the entire package useless. \nPrior to that, the tent performed great.', 'OriginalProductName': 'REI Co-op Wonderland 6 Tent'}
# {'review_id': '318719234', 'product_id': '202982', 'rating': 2, 'title': 'Not as good as 1st gen Kingdom 6', 'ReviewText': 'Kingdom \n\nAfter 8 years of consistent use, we were looking to replace our Kingdom 6. The Kingdom was everything we wanted in a tent. It kept us dry during heavy rain storms in remote places. \n\nThe Wonderland went back to the store after the first use. First, we had moisture in the tent after a light rain. The Kingdom also had this complaint from people, but we had optimized the set up so that it could withstand high winds and big downpours. \n\nMaybe the Wonderland could have been optimized, but my second point is that the tent is simply too big. There is no vestibule built into the rain fly like there was on the Kingdom 6. To have a covered vestibule on the Wonderland, we had to set up the Mudroom - which was too large for the State Park camping pad we were on.\n\nThe Kingdom 6’s modularity was great. You have a vestibule by default, and could add the Mudroom/Garage if you needed it. The Wonderland’s added ventilation is a nice thought, but that is the only upgrade that comes to mind. Everything else is a step back from they made in 2015. \n\nWe’ve opted to repair the seams in the Kingdom until REI, or someone else, comes out with something better.', 'OriginalProductName': 'REI Co-op Wonderland 6 Tent'}
# {'review_id': '318126359', 'product_id': '202982', 'rating': 1, 'title': 'Their tents are throw away tents at an outfitter.', 'ReviewText': "My guides switched the Kingdom tent recently. This appears to be it's replacement. We will be purchasing tents elsewhere since they offer no assistance if you have a problem with poles even if the tent is brand new. They send you to a company that will repair or replace your poles...in a month or two!  I have two different outfitter tents and have had them overnight poles when we had a problem. So these tents are throw away as far as I am concerned. No support, no parts, just buy a similar tent on Amazon for a third of the price then throw it away when it breaks.", 'OriginalProductName': 'REI Co-op Wonderland 6 Tent'}
# {'review_id': '315836617', 'product_id': '202982', 'rating': 1, 'title': 'Remind me never to buy REI brand gear again', 'ReviewText': "After just over one year and on it's third use a pole snapped while setting up the tent.  I took it to REI and they said they'd dropped their warranty to only a year and wouldn't cover it.  I can understand why they dropped the return policy of anything for any reason - people were abusing it, but this was a legitimate warranty problem.  Poles should not snap on their third use.  Guess that tells you how much they believe in their own products.", 'OriginalProductName': 'REI Co-op Wonderland 6 Tent'}

# %%
bad_reviews
# Out:
# [{'review_id': '346891208',
#   'product_id': '189281',
#   'rating': 1,
#   'title': 'Poor zipper',
#   'ReviewText': 'The zipper broke on 1st use, just separated in the middle. And we could not get it back on the track because there is no start anywhere.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 4',
#   'themes': ['zipper quality', 'durability', 'customer service']},
#  {'review_id': '256830169',
#   'product_id': '189281',
#   'rating': 1,
#   'title': 'Product delivered broken',
#   'ReviewText': 'Tent arrived with the shock-cord in one of the tent poles already snapped.  When I tried to assemble a second pole that shock-cord snapped too.  Good thing we set it up before attempting to go camping.  This was purchased via the REI Outlet.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 4',
#   'themes': ['quality control', 'shipping issues', 'product durability']},
#  {'review_id': '345639673',
#   'product_id': '204311',
#   'rating': 1,
#   'title': 'Arrived Used and With Broken Parts',
#   'ReviewText': 'Ordered this for family camping trips. Thank goodness I put it together ahead of our trip. The poles came with scrapes and scratches and one of the shock cords was broken.\n\nI would return, but REI didn’t have the correct footprint in stock so I had to get it from somewhere else. Additionally, REI does not have these tents in stock, so a replacement is not possible.\n\nI won’t buy anything else if I can’t get all the parts at REI. Not worth the hassle of being stuck with something subpar.',
#   'OriginalProductName': 'The North Face Wawona 6 Tent',
#   'themes': ['poor quality control',
#    'missing parts',
#    'customer service',
#    'product availability']},
#  {'review_id': '345446761',
#   'product_id': '204311',
#   'rating': 2,
#   'title': 'Buy a different tent',
#   'ReviewText': 'I have the previous version of this tent I guess. Looks like they may have made some changes. I have had mine for a few years now but have only used it half a dozen times. It’s not my favorite tent and now the floor almost seems like it has shrank. When I set it up there is a section of the floor that is raised up with a fold in it. I’t weird. I talked to REI about it and they don’t take returns for tents after a year (or something like that). I want to exchange it for a different one like maybe the REI Kingdom. I’ll try and get it set up in my backyard and snap some pictures of what’s going on. REI told me to contact North Face directly. I have a trip planned next month and am not excited about using this tent but am not about to shell out more money for a better one until I hear back from North Face.',
#   'OriginalProductName': 'The North Face Wawona 6 Tent',
#   'themes': ['product quality',
#    'customer service',
#    'return policy',
#    'product comparison']},
#  {'review_id': '344760907',
#   'product_id': '202274',
#   'rating': 1,
#   'title': 'Difficult to assemble',
#   'ReviewText': 'This is my 4th REI tent. I love the first three but this one is going back for a number of reasons. My first issue is with assembling the tent. I had my husband helping me with this and I am surprised we didn’t come to blows because this was the most frustrating and difficult tent I have ever tried to assemble. For context, I have a Base Camp 6 that I have put up by myself many times so it isn’t lack of experience. Once we finally got the tent up, the next thing I noticed was the lack of storage inside the tent. There is room for pockets at both ends of the tent but there aren’t any at the back or on the sides of the tent. I can’t be the only one who likes a pocket near my head for glasses and head lamp storage. When we took the tent down at the end of our trip, it was an absolute nightmare fitting back in the bag it came in. If you don’t fold it just right, it isn’t going back in that bag without a fight. Do not attempt this while hangry. On a positive note, the tent did keep us dry during a couple of strong storms. The rainfly doesn’t look like it would be protective but it does a solid job keeping the rain out. On a more positive note, REI has a very generous return policy for members and I am able to return this tent and get one that is a better fit for me. I would not repurchase or recommend this particular tent.',
#   'OriginalProductName': 'REI Co-op Skyward 4 Tent',
#   'themes': ['Assembly Difficulty',
#    'Lack of Storage',
#    'Packing Difficulty',
#    'Waterproof Ability',
#    'Return Policy']},
#  {'review_id': '340559495',
#   'product_id': '202274',
#   'rating': 2,
#   'title': 'Had to return',
#   'ReviewText': 'I love REI and a great deal so when I saw this tent on sale I had to buy it. Sadly I also had to return it after spending a day trying to set it up. I see someone else had a similar comment about the fit of the poles and wished I  would have read that review before buying it because I could have saved hours wondering if I was doing something wrong setting it up. I really would have loved this tent but I will be looking for a new one.',
#   'OriginalProductName': 'REI Co-op Skyward 4 Tent',
#   'themes': ['difficulty in setup', 'pole fit issues', 'disappointment']},
#  {'review_id': '345125723',
#   'product_id': '189270',
#   'rating': 2,
#   'title': 'Leaky tent',
#   'ReviewText': 'I took this tent out one time with the rain fly on. It started raining and the zipper started leaking and water got into the tent. Not only that but the rain fly barely even covers the netting of the tent itself. Any rain with wind will cause it to hit the netting and get your tent wet. It’s a great tent if you’re not planning on camping in the rain.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3',
#   'themes': ['leaking zipper',
#    'inadequate rain fly coverage',
#    'not suitable for rainy conditions']},
#  {'review_id': '344001528',
#   'product_id': '189270',
#   'rating': 1,
#   'title': 'Cheap quality',
#   'ReviewText': 'Cheap quality, poor design. I expected better from REI.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3',
#   'themes': ['quality', 'design', 'expectations']},
#  {'review_id': '338533330',
#   'product_id': '189270',
#   'rating': 1,
#   'title': '“Duped” by outlet price',
#   'ReviewText': 'Can’t believe I found this exact tent at Costco for same “Outlet” price at REI . I thought REI was giving me a deal ? Not so . Last time I buy from your company.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3',
#   'themes': ['pricing', 'customer service', 'trust']},
#  {'review_id': '323971222',
#   'product_id': '189270',
#   'rating': 1,
#   'title': 'Great in dry weather',
#   'ReviewText': "The bathtub leaks on this tent. It's not reliable in the rain.",
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3',
#   'themes': ['waterproofing', 'reliability', 'rain protection']},
#  {'review_id': '313104146',
#   'product_id': '189270',
#   'rating': 2,
#   'title': 'Cheap and limited instructions!',
#   'ReviewText': 'Purchased this tent thinking it would be a cheap starter tent to get back into camping. Cheap us right. The material seemed paper thin and there were limited instructions. The rain fly provides little protection above the door and is complicate to install. I immediately returned it and will be investing in a better quality brand.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3',
#   'themes': ['Poor Quality',
#    'Limited Instructions',
#    'Difficult Assembly',
#    'Inadequate Rain Protection']},
#  {'review_id': '308366193',
#   'product_id': '189270',
#   'rating': 1,
#   'title': None,
#   'ReviewText': "This tent has absolutely no instruction for how to use the rainfly.  The instructions say to use youtube but I can't find naything on youtube",
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 3',
#   'themes': ['missing instructions',
#    'poor customer support',
#    'difficulty in setup']},
#  {'review_id': '346895284',
#   'product_id': '185632',
#   'rating': 2,
#   'title': 'I’m concerned about longevity',
#   'ReviewText': 'Seems nice mostly, if it holds up. But the fly is tearing at 2 seams after the first use so I’m not feeling confident.',
#   'OriginalProductName': 'REI Co-op Half Dome SL 2+ Tent',
#   'themes': ['Durability', 'Quality', 'Customer Service']},
#  {'review_id': '345567461',
#   'product_id': '185632',
#   'rating': 1,
#   'title': 'Bent Poles/ripped fly',
#   'ReviewText': 'The poles bent and ripped into fly with one day of wind. Of course this happened 3 days after the 1 year return for REI.',
#   'OriginalProductName': 'REI Co-op Half Dome SL 2+ Tent',
#   'themes': ['poor quality', 'durability', 'customer service']},
#  {'review_id': '305343712',
#   'product_id': '189282',
#   'rating': 2,
#   'title': 'Directions incomplete and not going to be water pr',
#   'ReviewText': "The rain fly looks cool but doesnt cover the no seum mesh at the poles when the wind blows and it barely covers the side mesh.  The instructions omit the rain fly and after working in sporting goods back in college and setting up 100's of dome tents I couldn't figure it out.  Fortunately didn't rain.   I gave it 2 stars because the poles seem sturdy but you cant get parts for it so stick to a  bigger name brand tent.",
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 6',
#   'themes': ['Incomplete directions',
#    'Issues with rain fly coverage',
#    'Sturdiness of poles',
#    'Availability of parts']},
#  {'review_id': '263336847',
#   'product_id': '189282',
#   'rating': 2,
#   'title': 'Spacious but challenging',
#   'ReviewText': 'The tent is spacious but the zippers often get stuck and it was impossible to fold back up and fit into the storage bag.',
#   'OriginalProductName': 'Alpine Mountain Gear Weekender Tent 6',
#   'themes': ['zippers issue', 'spacious', 'folding challenge']},
#  {'review_id': '346866927',
#   'product_id': '204308',
#   'rating': 1,
#   'title': 'Poles bent randomly',
#   'ReviewText': "The poles bent and North Face wouldn't take responsibility for it",
#   'OriginalProductName': 'The North Face Stormbreak 3 Tent',
#   'themes': ['durability', 'customer service', 'defective product']},
#  {'review_id': '345641820',
#   'product_id': '202982',
#   'rating': 2,
#   'title': 'Save your money',
#   'ReviewText': 'The tent was nice, however I was only able to sleep in it 5 total nights because once any sort of wind came through, the poles bent and I had to cut my camping trip short since it became unusable. I expected a tent of this price to stand through one storm.',
#   'OriginalProductName': 'REI Co-op Wonderland 6 Tent',
#   'themes': ['durability', 'weather resistance', 'value for money']},
#  {'review_id': '336538558',
#   'product_id': '202982',
#   'rating': 1,
#   'title': 'Worst tent I have ever owned',
#   'ReviewText': 'This tent had no ability to stand up to wind. We had some wind camping in the desert and multiple poles snapped and the tent collapsed, this is with it properly staked and guy-lined down mind you. This was on our 5th or 6th use of the tent. I\'ve been camping for most of my life and have camped many times in heavier winds with tents that survived just fine. \n\nREI then refused to accept a return for "damage", even though their product is flawed. At the time of writing this review it has 22% 1 star reviews and most mention snapped poles, many even during setup. We haven\'t even had this tent a year and they won\'t accept a return or cover it under warranty.  So much for the "100% satisfaction guarantee", the tent is literally still within the "I don\'t like it" return window, but because it completely failed us and is damaged, REI won\'t take it back. \n\nMy experience with this horrible tent and REI telling me to pound sand is the type of thing that will turn me from a lifetime REI customer to someone who won\'t be shopping at REI again.',
#   'OriginalProductName': 'REI Co-op Wonderland 6 Tent',
#   'themes': ['poor quality',
#    'unreliable in windy conditions',
#    'poor customer service',
#    'broken poles',
#    'disappointing experience']},
#  {'review_id': '319993468',
#   'product_id': '202982',
#   'rating': 2,
#   'title': 'Great, except lasted two times.',
#   'ReviewText': 'We purchased the tent, footprint, and mudroom for 6-person Wonderland to introduce our kids to camping (parents are experienced hikers/campers).  On the second use one of the tension poles tore a huge hole in the mesh. Functionally rendering the entire package useless. \nPrior to that, the tent performed great.',
#   'OriginalProductName': 'REI Co-op Wonderland 6 Tent',
#   'themes': ['Durability', 'Quality', 'Customer Service']},
#  {'review_id': '318719234',
#   'product_id': '202982',
#   'rating': 2,
#   'title': 'Not as good as 1st gen Kingdom 6',
#   'ReviewText': 'Kingdom \n\nAfter 8 years of consistent use, we were looking to replace our Kingdom 6. The Kingdom was everything we wanted in a tent. It kept us dry during heavy rain storms in remote places. \n\nThe Wonderland went back to the store after the first use. First, we had moisture in the tent after a light rain. The Kingdom also had this complaint from people, but we had optimized the set up so that it could withstand high winds and big downpours. \n\nMaybe the Wonderland could have been optimized, but my second point is that the tent is simply too big. There is no vestibule built into the rain fly like there was on the Kingdom 6. To have a covered vestibule on the Wonderland, we had to set up the Mudroom - which was too large for the State Park camping pad we were on.\n\nThe Kingdom 6’s modularity was great. You have a vestibule by default, and could add the Mudroom/Garage if you needed it. The Wonderland’s added ventilation is a nice thought, but that is the only upgrade that comes to mind. Everything else is a step back from they made in 2015. \n\nWe’ve opted to repair the seams in the Kingdom until REI, or someone else, comes out with something better.',
#   'OriginalProductName': 'REI Co-op Wonderland 6 Tent',
#   'themes': ['moisture resistance',
#    'size',
#    'modularity',
#    'ventilation',
#    'customer service']},
#  {'review_id': '318126359',
#   'product_id': '202982',
#   'rating': 1,
#   'title': 'Their tents are throw away tents at an outfitter.',
#   'ReviewText': "My guides switched the Kingdom tent recently. This appears to be it's replacement. We will be purchasing tents elsewhere since they offer no assistance if you have a problem with poles even if the tent is brand new. They send you to a company that will repair or replace your poles...in a month or two!  I have two different outfitter tents and have had them overnight poles when we had a problem. So these tents are throw away as far as I am concerned. No support, no parts, just buy a similar tent on Amazon for a third of the price then throw it away when it breaks.",
#   'OriginalProductName': 'REI Co-op Wonderland 6 Tent',
#   'themes': ['poor customer support',
#    'low quality materials',
#    'lack of replacement parts']},
#  {'review_id': '315836617',
#   'product_id': '202982',
#   'rating': 1,
#   'title': 'Remind me never to buy REI brand gear again',
#   'ReviewText': "After just over one year and on it's third use a pole snapped while setting up the tent.  I took it to REI and they said they'd dropped their warranty to only a year and wouldn't cover it.  I can understand why they dropped the return policy of anything for any reason - people were abusing it, but this was a legitimate warranty problem.  Poles should not snap on their third use.  Guess that tells you how much they believe in their own products.",
#   'OriginalProductName': 'REI Co-op Wonderland 6 Tent',
#   'themes': ['poor durability', 'customer service issue', 'warranty policy']}]

# %%
list_of_themes = []
for item in bad_reviews:
    list_of_themes.extend(item["themes"])

# %%
list_of_themes
# Out:
# ['zipper quality',
#  'durability',
#  'customer service',
#  'quality control',
#  'shipping issues',
#  'product durability',
#  'poor quality control',
#  'missing parts',
#  'customer service',
#  'product availability',
#  'product quality',
#  'customer service',
#  'return policy',
#  'product comparison',
#  'Assembly Difficulty',
#  'Lack of Storage',
#  'Packing Difficulty',
#  'Waterproof Ability',
#  'Return Policy',
#  'difficulty in setup',
#  'pole fit issues',
#  'disappointment',
#  'leaking zipper',
#  'inadequate rain fly coverage',
#  'not suitable for rainy conditions',
#  'quality',
#  'design',
#  'expectations',
#  'pricing',
#  'customer service',
#  'trust',
#  'waterproofing',
#  'reliability',
#  'rain protection',
#  'Poor Quality',
#  'Limited Instructions',
#  'Difficult Assembly',
#  'Inadequate Rain Protection',
#  'missing instructions',
#  'poor customer support',
#  'difficulty in setup',
#  'Durability',
#  'Quality',
#  'Customer Service',
#  'poor quality',
#  'durability',
#  'customer service',
#  'Incomplete directions',
#  'Issues with rain fly coverage',
#  'Sturdiness of poles',
#  'Availability of parts',
#  'zippers issue',
#  'spacious',
#  'folding challenge',
#  'durability',
#  'customer service',
#  'defective product',
#  'durability',
#  'weather resistance',
#  'value for money',
#  'poor quality',
#  'unreliable in windy conditions',
#  'poor customer service',
#  'broken poles',
#  'disappointing experience',
#  'Durability',
#  'Quality',
#  'Customer Service',
#  'moisture resistance',
#  'size',
#  'modularity',
#  'ventilation',
#  'customer service',
#  'poor customer support',
#  'low quality materials',
#  'lack of replacement parts',
#  'poor durability',
#  'customer service issue',
#  'warranty policy']
